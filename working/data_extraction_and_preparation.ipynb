# %%
import logging
from operator import itemgetter
from IPython.display import display, SVG
import pandas as pd
from chembl_webresource_client.new_client import new_client
molecule = new_client.molecule
molecule.set_format('json')

# %%
#obtain all biotherapeutic molecules with no Rule-of-Five violations
biotherapeutics = molecule.filter(biotherapeutic__isnull=False).filter(molecule_properties__num_ro5_violations=0)

# %%
len(biotherapeutics)
# Out:
# 1150

# %%
biotherapeutics_df = pd.DataFrame(list(biotherapeutics.all()))

# %%
biotherapeutics_df
# Out:
#      atc_classifications  availability_type  \
# 0                     []               -1.0
# 1                     []               -1.0
# 2                     []               -1.0
# 3                     []               -1.0
# 4                     []               -1.0
# ...                  ...                ...
# 1145                  []               -1.0
# 1146                  []               -1.0
# 1147                  []               -1.0
# 1148                  []               -1.0
# 1149                  []               -1.0
#
#                                          biotherapeutic  black_box_warning  \
# 0     {'biocomponents': [], 'description': None, 'he...                  0
# 1     {'biocomponents': [], 'description': None, 'he...                  0
# 2     {'biocomponents': [], 'description': None, 'he...                  0
# 3     {'biocomponents': [], 'description': None, 'he...                  0
# 4     {'biocomponents': [], 'description': None, 'he...                  0
# ...                                                 ...                ...
# 1145  {'biocomponents': [], 'description': None, 'he...                  0
# 1146  {'biocomponents': [], 'description': None, 'he...                  0
# 1147  {'biocomponents': [], 'description': None, 'he...                  0
# 1148  {'biocomponents': [], 'description': None, 'he...                  0
# 1149  {'biocomponents': [], 'description': None, 'he...                  0
#
#       chebi_par_id  chirality cross_references  dosed_ingredient  \
# 0              NaN         -1               []             False
# 1              NaN         -1               []             False
# 2              NaN         -1               []             False
# 3              NaN         -1               []             False
# 4              NaN         -1               []             False
# ...            ...        ...              ...               ...
# 1145           NaN         -1               []             False
# 1146           NaN         -1               []             False
# 1147           NaN         -1               []             False
# 1148           NaN         -1               []             False
# 1149           NaN         -1               []             False
#
#       first_approval  first_in_class  ... topical usan_stem  \
# 0                NaN              -1  ...   False      None
# 1                NaN              -1  ...   False      None
# 2                NaN              -1  ...   False      None
# 3                NaN              -1  ...   False      None
# 4                NaN              -1  ...   False      None
# ...              ...             ...  ...     ...       ...
# 1145             NaN              -1  ...   False      None
# 1146             NaN              -1  ...   False      None
# 1147             NaN              -1  ...   False      None
# 1148             NaN              -1  ...   False      None
# 1149             NaN              -1  ...   False      None
#
#       usan_stem_definition  usan_substem usan_year withdrawn_class  \
# 0                     None          None       NaN            None
# 1                     None          None       NaN            None
# 2                     None          None       NaN            None
# 3                     None          None       NaN            None
# 4                     None          None       NaN            None
# ...                    ...           ...       ...             ...
# 1145                  None          None       NaN            None
# 1146                  None          None       NaN            None
# 1147                  None          None       NaN            None
# 1148                  None          None       NaN            None
# 1149                  None          None       NaN            None
#
#      withdrawn_country withdrawn_flag withdrawn_reason withdrawn_year
# 0                 None          False             None           None
# 1                 None          False             None           None
# 2                 None          False             None           None
# 3                 None          False             None           None
# 4                 None          False             None           None
# ...                ...            ...              ...            ...
# 1145              None          False             None           None
# 1146              None          False             None           None
# 1147              None          False             None           None
# 1148              None          False             None           None
# 1149              None          False             None           None
#
# [1150 rows x 38 columns]

# %%
#load the csv file with all A-type assaya with bos taurus as the target
assay_A = pd.read_csv('assay_bos_taurus.csv',sep=';')

# %%
assay_A
# Out:
#          ChEMBL ID Assay Type  \
# 0    CHEMBL3863928          A
# 1    CHEMBL3424919          A
# 2     CHEMBL642716          A
# 3    CHEMBL1285656          A
# 4    CHEMBL4180781          A
# ..             ...        ...
# 602   CHEMBL623217          A
# 603   CHEMBL633370          A
# 604   CHEMBL623555          A
# 605   CHEMBL635065          A
# 606   CHEMBL634760          A
#
#                                            Description    Organism  Compounds  \
# 0    Binding affinity to BSA assessed as dissociati...  Bos taurus          1
# 1    Cytotoxicity against bovine MDBK cells assesse...  Bos taurus         22
# 2    Delta Tm value ( Tmdrug-DNA )-TmDNA ) was obta...  Bos taurus          1
# 3    Cytotoxicity against BAEC assessed as cell via...  Bos taurus          2
# 4    Binding affinity to calf thymus duplex DNA ass...  Bos taurus          1
# ..                                                 ...         ...        ...
# 602  Association constant of binding of compound wi...  Bos taurus          3
# 603  Tested for inhibition of carbonic anhydrase 4 ...  Bos taurus          2
# 604  Specificity constant of the bovine serum album...  Bos taurus          1
# 605       Solubility against bovine alpha-chymotrypsin  Bos taurus          1
# 606  Michaelis constant for hydrolysis catalyzed by...  Bos taurus          2
#
#      Activities BAO Format ID             BAO Format  Confidence Score  \
# 0             1   BAO_0000357  single protein format                 9
# 1            23   BAO_0000219      cell-based format                 0
# 2             1   BAO_0000218  organism-based format                 1
# 3             2   BAO_0000019           assay format                 0
# 4             1   BAO_0000225    nucleic acid format                 3
# ..          ...           ...                    ...               ...
# 602           3   BAO_0000218  organism-based format                 1
# 603           2   BAO_0000218  organism-based format                 1
# 604           1   BAO_0000019           assay format                 0
# 605           1   BAO_0000218  organism-based format                 1
# 606           2   BAO_0000218  organism-based format                 1
#
#                                       Confidence Label  ...  \
# 0            9 - Direct single protein target assigned  ...
# 1    0 - Default value - Target unknown or has yet ...  ...
# 2                 1 - Target assigned is non-molecular  ...
# 3    0 - Default value - Target unknown or has yet ...  ...
# 4    3 - Target assigned is molecular non-protein t...  ...
# ..                                                 ...  ...
# 602               1 - Target assigned is non-molecular  ...
# 603               1 - Target assigned is non-molecular  ...
# 604  0 - Default value - Target unknown or has yet ...  ...
# 605               1 - Target assigned is non-molecular  ...
# 606               1 - Target assigned is non-molecular  ...
#
#                       Journal Volume  First Page Last Page Assay Parameters  \
# 0                  J Med Chem     59       10788     10793              NaN
# 1    Bioorg. Med. Chem. Lett.     25        2401      2404              NaN
# 2               J. Med. Chem.     43        4711      4720              NaN
# 3          Eur. J. Med. Chem.     45        5309      5317              NaN
# 4             Bioorg Med Chem     25        6404      6411              NaN
# ..                        ...    ...         ...       ...              ...
# 602             J. Med. Chem.     39        1293      1302              NaN
# 603             J. Med. Chem.     43        4542      4551              NaN
# 604  Bioorg. Med. Chem. Lett.      8        1113      1116              NaN
# 605             J. Med. Chem.     30        1017      1023              NaN
# 606             J. Med. Chem.     25        1505      1507              NaN
#
#     Assay Classification L1 Assay Classification L2 Assay Classification L3  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 602                     NaN                     NaN                     NaN
# 603                     NaN                     NaN                     NaN
# 604                     NaN                     NaN                     NaN
# 605                     NaN                     NaN                     NaN
# 606                     NaN                     NaN                     NaN
#
#     Variant Sequence Accession Variant Sequence Mutation
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 602                        NaN                       NaN
# 603                        NaN                       NaN
# 604                        NaN                       NaN
# 605                        NaN                       NaN
# 606                        NaN                       NaN
#
# [607 rows x 32 columns]

# %%
#obtain all bioactivities for all the molecules in assay_A
bioact = pd.DataFrame()
for chembl_id in assay_A['ChEMBL ID']:
    records = new_client.activity.filter(assay_chembl_id=chembl_id)
    records_df = pd.DataFrame(list(records.all()))
    bioact = bioact.append(records_df)

# %%
bioact.reset_index(drop=True, inplace=True)

# %%
bioact
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None     16771318                  []   CHEMBL3863928
# 1                None     15237924                  []   CHEMBL3424919
# 2                None     15237925                  []   CHEMBL3424919
# 3                None     15237926                  []   CHEMBL3424919
# 4                None     15237927                  []   CHEMBL3424919
# ...               ...          ...                 ...             ...
# 3129             None       502877                  []    CHEMBL633370
# 3130             None       203575                  []    CHEMBL623555
# 3131             None       455335                  []    CHEMBL635065
# 3132             None       474723                  []    CHEMBL634760
# 3133             None       490403                  []    CHEMBL634760
#
#                                       assay_description assay_type  \
# 0     Binding affinity to BSA assessed as dissociati...          A
# 1     Cytotoxicity against bovine MDBK cells assesse...          A
# 2     Cytotoxicity against bovine MDBK cells assesse...          A
# 3     Cytotoxicity against bovine MDBK cells assesse...          A
# 4     Cytotoxicity against bovine MDBK cells assesse...          A
# ...                                                 ...        ...
# 3129  Tested for inhibition of carbonic anhydrase 4 ...          A
# 3130  Specificity constant of the bovine serum album...          A
# 3131       Solubility against bovine alpha-chymotrypsin          A
# 3132  Michaelis constant for hydrolysis catalyzed by...          A
# 3133  Michaelis constant for hydrolysis catalyzed by...          A
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000179  BAO_0000357
# 1                       None                   None  BAO_0000187  BAO_0000219
# 2                       None                   None  BAO_0000187  BAO_0000219
# 3                       None                   None  BAO_0000187  BAO_0000219
# 4                       None                   None  BAO_0000187  BAO_0000219
# ...                      ...                    ...          ...          ...
# 3129                    None                   None  BAO_0002135  BAO_0000218
# 3130                    None                   None  BAO_0000179  BAO_0000019
# 3131                    None                   None  BAO_0002135  BAO_0000218
# 3132                    None                   None  BAO_0000179  BAO_0000218
# 3133                    None                   None  BAO_0000179  BAO_0000218
#
#       ... target_organism target_pref_name target_tax_id text_value  toid  \
# 0     ...      Bos taurus    Serum albumin          9913       None  None
# 1     ...            None            ADMET          None       None  None
# 2     ...            None            ADMET          None       None  None
# 3     ...            None            ADMET          None       None  None
# 4     ...            None            ADMET          None       None  None
# ...   ...             ...              ...           ...        ...   ...
# 3129  ...      Bos taurus       Bos taurus          9913       None  None
# 3130  ...            None            ADMET          None       None  None
# 3131  ...      Bos taurus       Bos taurus          9913       None  None
# 3132  ...      Bos taurus       Bos taurus          9913       None  None
# 3133  ...      Bos taurus       Bos taurus          9913       None  None
#
#                   type units    uo_units upper_value      value
# 0                    K    /s        None        None     1700.0
# 1                 CC50    uM  UO_0000065        None      100.0
# 2                 CC50    uM  UO_0000065        None       64.0
# 3                 CC50    uM  UO_0000065        None      100.0
# 4                 CC50    uM  UO_0000065        None      100.0
# ...                ...   ...         ...         ...        ...
# 3129        Solubility    mM  UO_0000065        None       47.0
# 3130  (kcat/KM)/kuncat   M-1        None        None  2600000.0
# 3131        Solubility    uM  UO_0000065        None       10.0
# 3132         Vmax / Km  None        None        None    1.06E-8
# 3133         Vmax / Km  None        None        None   0.000297
#
# [3134 rows x 45 columns]

# %%
# form a temperary dataframe "ml_bioact" without repetitive molecules
# count the number of bioactivities for each molecule
seen = {}
ml_bioact = pd.DataFrame()
for index, row in bioact.iterrows():
    molecule_chembl_id = row['molecule_chembl_id']
    if molecule_chembl_id not in seen:
        seen[molecule_chembl_id] = 1
        ml_bioact = ml_bioact.append(row)
    else:
        seen[molecule_chembl_id] += 1
        print(molecule_chembl_id, seen[molecule_chembl_id])
# Out:
# CHEMBL2057884 2
# CHEMBL4548775 2
# CHEMBL4444942 2
# CHEMBL435087 2
# CHEMBL1643 2
# CHEMBL418899 2
# CHEMBL418899 3
# CHEMBL1643 3
# CHEMBL435087 3
# CHEMBL564201 2
# CHEMBL1093906 2
# CHEMBL866 2
# CHEMBL1643 4
# CHEMBL184 2
# CHEMBL564201 3
# CHEMBL418899 4
# CHEMBL1914709 2
# CHEMBL4464312 2
# CHEMBL1914709 3
# CHEMBL1233636 2
# CHEMBL418899 5
# CHEMBL1940452 2
# CHEMBL184 3
# CHEMBL866 3
# CHEMBL418899 6
# CHEMBL98778 2
# CHEMBL564201 4
# CHEMBL1643 5
# CHEMBL1996518 2
# CHEMBL495806 2
# CHEMBL4164983 2
# CHEMBL4169485 2
# CHEMBL4161565 2
# CHEMBL4161158 2
# CHEMBL4174325 2
# CHEMBL1914709 4
# CHEMBL418899 7
# CHEMBL2368591 2
# CHEMBL2204494 2
# CHEMBL493287 2
# CHEMBL447878 2
# CHEMBL4175069 2
# CHEMBL4163914 2
# CHEMBL2368591 3
# CHEMBL3288759 2
# CHEMBL13556 2
# CHEMBL13556 3
# CHEMBL3392174 2
# CHEMBL478007 2
# CHEMBL106 2
# CHEMBL418899 8
# CHEMBL4250329 2
# CHEMBL4250329 3
# CHEMBL418899 9
# CHEMBL564201 5
# CHEMBL4244247 2
# CHEMBL151997 2
# CHEMBL109904 2
# CHEMBL4175069 3
# CHEMBL4163914 3
# CHEMBL2393130 2
# CHEMBL4161990 2
# CHEMBL1996518 3
# CHEMBL4435230 2
# CHEMBL4175069 4
# CHEMBL4163914 4
# CHEMBL487509 2
# CHEMBL500870 2
# CHEMBL487714 2
# CHEMBL487715 2
# CHEMBL519413 2
# CHEMBL486280 2
# CHEMBL306226 2
# CHEMBL309135 2
# CHEMBL473721 2
# CHEMBL112 2
# CHEMBL139 2
# CHEMBL2393130 3
# CHEMBL83 2
# CHEMBL4175069 5
# CHEMBL4163914 5
# CHEMBL4464312 3
# CHEMBL4214782 2
# CHEMBL4244247 3
# CHEMBL4571877 2
# CHEMBL1914709 5
# CHEMBL1914709 6
# CHEMBL1697766 3
# CHEMBL168001 2
# CHEMBL13556 4
# CHEMBL477 2
# CHEMBL2369146 2
# CHEMBL1554 2
# CHEMBL269138 2
# CHEMBL8194 2
# CHEMBL7852 2
# CHEMBL8180 2
# CHEMBL7777 2
# CHEMBL7958 2
# CHEMBL7952 2
# CHEMBL7333 2
# CHEMBL7630 2
# CHEMBL7839 2
# CHEMBL7129 2
# CHEMBL7424 2
# CHEMBL7816 2
# CHEMBL7738 2
# CHEMBL7706 2
# CHEMBL7309 2
# CHEMBL7825 2
# CHEMBL8134 2
# CHEMBL2112699 2
# CHEMBL2111890 2
# CHEMBL168001 3
# CHEMBL339398 2
# CHEMBL132957 2
# CHEMBL168001 4
# CHEMBL2304162 2
# CHEMBL477 3
# CHEMBL1090 3
# CHEMBL37605 2
# CHEMBL417508 2
# CHEMBL37605 3
# CHEMBL417508 3
# CHEMBL13556 5
# CHEMBL7780 2
# CHEMBL37605 4
# CHEMBL417508 4

# %%
# for assay A, there are 2269 molecules 
len(ml_bioact)
# Out:
# 2269

# %%
# obtain information for each molecule in ml_bioact based on their chembl_ids and 
mol_info = pd.DataFrame()
for i in range(0, len(ml_bioact), 100):
    for molecule_chembl_id in ml_bioact[i:i+100]['molecule_chembl_id']:
        mol = molecule.get(molecule_chembl_id)
        mol_df = pd.DataFrame(list(mol.items())).transpose()
        mol_df = mol_df.rename(columns=mol_df.iloc[0]).drop(mol_df.index[0])
        mol_info = mol_info.append(mol_df)
mol_info.reset_index(drop=True, inplace=True)

# %%
mol_info
# Out:
#      atc_classifications availability_type biotherapeutic black_box_warning  \
# 0                     []                -1           None                 0
# 1                     []                -1           None                 0
# 2                     []                -1           None                 0
# 3                     []                -1           None                 0
# 4                     []                -1           None                 0
# ...                  ...               ...            ...               ...
# 2264                  []                -1           None                 0
# 2265                  []                -1           None                 0
# 2266  [D05AD02, D05BA02]                 1           None                 1
# 2267                  []                -1           None                 0
# 2268                  []                -1           None                 0
#
#      chebi_par_id chirality  \
# 0           43355        -1
# 1            None        -1
# 2            None        -1
# 3            None        -1
# 4            None        -1
# ...           ...       ...
# 2264         None        -1
# 2265         None        -1
# 2266        18358         2
# 2267         None        -1
# 2268         None        -1
#
#                                        cross_references dosed_ingredient  \
# 0                                                    []            False
# 1                                                    []            False
# 2                                                    []            False
# 3                                                    []            False
# 4                                                    []            False
# ...                                                 ...              ...
# 2264                                                 []            False
# 2265                                                 []            False
# 2266  [{'xref_id': 'methoxsalen', 'xref_name': 'meth...             True
# 2267                                                 []            False
# 2268                                                 []            False
#
#      first_approval first_in_class  ... topical usan_stem  \
# 0              None             -1  ...   False      None
# 1              None             -1  ...   False      None
# 2              None             -1  ...   False      None
# 3              None             -1  ...   False      None
# 4              None             -1  ...   False      None
# ...             ...            ...  ...     ...       ...
# 2264           None             -1  ...   False      None
# 2265           None             -1  ...   False      None
# 2266           1954              0  ...    True     -sal-
# 2267           None             -1  ...   False      None
# 2268           None             -1  ...   False      None
#
#                                    usan_stem_definition usan_substem  \
# 0                                                  None         None
# 1                                                  None         None
# 2                                                  None         None
# 3                                                  None         None
# 4                                                  None         None
# ...                                                 ...          ...
# 2264                                               None         None
# 2265                                               None         None
# 2266  anti-inflammatory agents (salicylic acid deriv...        -sal-
# 2267                                               None         None
# 2268                                               None         None
#
#      usan_year withdrawn_class withdrawn_country withdrawn_flag  \
# 0         None            None              None          False
# 1         None            None              None          False
# 2         None            None              None          False
# 3         None            None              None          False
# 4         None            None              None          False
# ...        ...             ...               ...            ...
# 2264      None            None              None          False
# 2265      None            None              None          False
# 2266      None            None              None          False
# 2267      None            None              None          False
# 2268      None            None              None          False
#
#      withdrawn_reason withdrawn_year
# 0                None           None
# 1                None           None
# 2                None           None
# 3                None           None
# 4                None           None
# ...               ...            ...
# 2264             None           None
# 2265             None           None
# 2266             None           None
# 2267             None           None
# 2268             None           None
#
# [2269 rows x 38 columns]

# %%
def find_bioactivity_for_single_molecule(molecule_chembl_id):
    bioact_for_single_molecule = []
    for ml_id, row_i in bioact.iterrows():
        smile_bioact = {}
        if row_i['molecule_chembl_id'] == molecule_chembl_id:
            smile_bioact['molecule_chembl_id'] = row_i['molecule_chembl_id']
            smile_bioact['type'] = row_i['type']
            smile_bioact['value'] = row_i['value']
            smile_bioact['units'] = row_i['units']
            for index, row_j in mol_info.iterrows():
                if row_j['molecule_chembl_id'] == molecule_chembl_id:
                    smile_bioact['canonical_smiles'] = row_j['molecule_structures']['canonical_smiles']
            bioact_for_single_molecule.append(smile_bioact)
    return bioact_for_single_molecule

# %%
molecule_chembl_id = 'CHEMBL71'

bioact_for_single_molecule = []
for ml_id, row_i in bioact.iterrows():
    smile_bioact = {}
    if row_i['molecule_chembl_id'] == molecule_chembl_id:
        smile_bioact['molecule_chembl_id'] = row_i['molecule_chembl_id']
        smile_bioact['type'] = row_i['type']
        smile_bioact['value'] = row_i['value']
        smile_bioact['units'] = row_i['units']
        for index, row_j in mol_info.iterrows():
            if row_j['molecule_chembl_id'] == molecule_chembl_id:
                smile_bioact['canonical_smiles'] = row_j['molecule_structures']['canonical_smiles']
        bioact_for_single_molecule.append(smile_bioact)

# %%
bioact_for_single_molecule
# Out:
# [{'molecule_chembl_id': 'CHEMBL71',
#   'type': 'Activity',
#   'value': None,
#   'units': None,
#   'canonical_smiles': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'molecule_chembl_id': 'CHEMBL71',
#   'type': 'logKd',
#   'value': '4.98',
#   'units': None,
#   'canonical_smiles': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'molecule_chembl_id': 'CHEMBL71',
#   'type': 'log K',
#   'value': '3.79',
#   'units': None,
#   'canonical_smiles': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'},
#  {'molecule_chembl_id': 'CHEMBL71',
#   'type': 'log K',
#   'value': '4.32',
#   'units': None,
#   'canonical_smiles': 'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21'}]

# %%
def obtain_molecule_image(molecule_chembl_id):
    molecule_chembl_id = 'CHEMBL71'
    image = new_client.image
    image.set_format('svg')
    svg = image.get(molecule_chembl_id)
    SVG(svg)

# %%
molecule_chembl_id = 'CHEMBL71'
image = new_client.image
image.set_format('svg')
svg = image.get(molecule_chembl_id)
SVG(svg)
